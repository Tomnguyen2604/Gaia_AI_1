# %% [markdown]
# # 🌍 Gaia - Mother Nature AI
#
# Run Gaia on Google Colab with free T4 GPU!
#
# **Steps:**
# 1. Enable GPU: Runtime → Change runtime type → T4 GPU
# 2. Run all cells below
# 3. Get your public URL from the last cell
# 4. Share and enjoy!
#
# **Note:** Session lasts 12 hours. Just restart if it expires.

# %%
# Check GPU
# !nvidia-smi

# %%
# Clone repository
# !git clone https://github.com/Tomnguyen2604/Gaia_AI_1.git
# %cd Gaia_AI_1

# %%
# Install dependencies
# !pip install -q -r requirements.txt

# %%
# Login to Hugging Face (required for Gemma model)
from huggingface_hub import notebook_login
notebook_login()

# %%
# Optional: Build RAG knowledge base
# Uncomment if you want RAG features
# !pip install sentence-transformers chromadb
# %cd server
# !python scripts/build_knowledge_base.py
# %cd ..

# %%
# Start Streamlit with public URL
# !npm install -g localtunnel
# !streamlit run server/scripts/chat.py &>/content/logs.txt & npx localtunnel --port 8501

# %% [markdown]
# ## 🎉 Your Gaia is Running!
#
# Copy the localtunnel URL from above and open it in your browser.
#
# **Tips:**
# - First load may take 30-60 seconds (model loading)
# - Session lasts 12 hours
# - To restart: Runtime → Restart runtime, then run all cells
#
# **Troubleshooting:**
# - If URL doesn't work, check logs: `!cat /content/logs.txt`
# - Make sure GPU is enabled in Runtime settings
